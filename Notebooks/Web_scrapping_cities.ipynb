# %% [markdown]
# ## 1. Import Libraries

# %%
import requests
from selenium import webdriver
from time import sleep
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import pandas as pd
import sys
sys.path.append('../')

# %%
import src.cleaning_web as fc

# %% [markdown]
# ## 2. Configure the Selenium tool to be used

# %%
opciones= Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
#para ocultarme como robot, pero me sigue diciendo que hay un software automatico usando chrome
opciones.add_experimental_option('useAutomationExtension', False)
opciones.add_argument('--start-maximized') #empezar maximizado
opciones.add_argument('user.data-dir=selenium') #guarda las cookies
opciones.add_argument('drive/adblock.crx') #adblocker
opciones.add_argument('--incognito')#incognito window

# %% [markdown]
# ## 3. We start with the web scraping of our data.

# %% [markdown]
# ### 3.1 We determined the cities to be used, which have been taken from our first Scoring data set.

# %% [markdown]
# *para que esta parte quede mejor sería importante exportar las ciudades directamente del csv, y agregarles la barra media a las ciudades que tienen un espacio dentro de su estructura*

# %%
cities = ['Aarhus', 'Adelaide', 'Albuquerque', 'Almaty', 'Amsterdam','Anchorage', 'Andorra', 'Ankara', 'Asheville', 'Asuncion','Athens', 'Atlanta', 'Auckland', 'Austin', 'Baku', 'Bali','Baltimore', 'Bangkok', 'Barcelona', 
          'Beijing', 'Beirut','Belfast', 'Belgrade', 'Bengaluru', 'Bergen','Berlin', 'Bern', 'Bilbao', 
          'Birmingham', 'Bogota', 'Boise','Bologna', 'Bordeaux', 'Boston', 'Boulder', 'Bozeman','Bratislava', 
          'Brighton', 'Brisbane', 'Bristol', 'Brno','Brussels', 'Bucharest', 'Budapest', 'Buenos-Aires', 'Buffalo',
          'Cairo', 'Calgary', 'Cambridge', 'cape-town', 'Caracas', 'Cardiff','Casablanca', 'Charleston', 'Charlotte', 
          'Chattanooga', 'Chennai','Chiang-Mai', 'Chicago', 'Chisinau', 'Christchurch', 'Cincinnati',
       'Cleveland', 'Cluj-Napoca', 'Cologne', 'Colorado-Springs','Columbus', 'Copenhagen', 'Cork', 'Curitiba', 'Dallas',
       'Dar-es-Salaam', 'Delhi', 'Denver', 'Des-Moines', 'Detroit','Doha', 'Dresden', 'Dubai', 'Dublin', 'Dusseldorf', 'Edinburgh',
       'Edmonton', 'Eindhoven', 'Eugene', 'Florence', 'Florianopolis','Fort-Collins', 'Frankfurt', 'Fukuoka', 'Gdansk',
       'Geneva', 'Gibraltar', 'Glasgow', 'Gothenburg', 'Grenoble','Guadalajara', 'Guatemala-City', 'Halifax', 'Hamburg', 'Hannover',
       'Havana', 'Helsinki', 'Ho-Chi-Minh-City', 'Hong-Kong', 'Honolulu','Houston', 'Hyderabad', 'Indianapolis', 'Innsbruck', 'Istanbul',
       'Jacksonville', 'Jakarta', 'Johannesburg', 'Kansas-City','Karlsruhe', 'Kathmandu', 'Kiev', 'Kingston', 'Knoxville',
       'Krakow', 'Kuala-Lumpur', 'Kyoto', 'Lagos', 'La-Paz','Las-Palmas-de-Gran-Canaria', 'Las-Vegas', 'Lausanne', 'Leeds',
       'Leipzig', 'Lille', 'Lima', 'Lisbon', 'Liverpool', 'Ljubljana','London', 'Los-Angeles', 'Louisville', 'Luxembourg', 'Lviv',
       'Lyon', 'Madison', 'Madrid', 'Malaga', 'Malmo', 'Managua','Manchester', 'Manila', 'Marseille', 'Medellin', 'Melbourne',
       'Memphis', 'Mexico-City', 'Miami', 'Milan', 'Milwaukee','Minneapolis-Saint-Paul', 'Minsk', 'Montevideo', 'Montreal',
       'Moscow', 'Mumbai', 'Munich', 'Nairobi', 'Nantes', 'Naples','Nashville', 'New-Orleans', 'New-York', 'Nice', 'Nicosia',
       'Oklahoma-City', 'Omaha', 'Orlando', 'Osaka', 'Oslo', 'Ottawa','Oulu', 'Oxford', 'Palo-Alto', 'Panama', 'Paris', 'Perth',
       'Philadelphia', 'Phnom-Penh', 'Phoenix', 'Phuket', 'Pittsburgh','Portland-or', 'Porto', 'Porto-Alegre', 'Prague', 'Providence',
       'Quebec', 'Quito', 'Raleigh', 'Reykjavik', 'Richmond', 'Riga','Rio-De-Janeiro', 'Riyadh', 'Rochester', 'Rome', 'Rotterdam',
       'Saint-Petersburg', 'Salt-Lake-City', 'San-Antonio', 'San-Diego','San-Francisco-Bay-Area', 'San-Jose', 'San-Juan',
       'San-Luis-Obispo', 'San-Salvador', 'Santiago', 'Santo-Domingo','Sao-Paulo', 'Sarajevo', 'Saskatoon', 'Seattle', 'Seoul',
       'Seville', 'Shanghai', 'Singapore', 'Skopje', 'Sofia', 'St-Louis','Stockholm', 'Stuttgart', 'Sydney', 'Taipei', 'Tallinn',
       'Tampa-Bay-Area', 'Tampere', 'Tartu', 'Tashkent', 'Tbilisi','Tehran', 'Tel-Aviv', 'The-Hague', 'Thessaloniki', 'Tokyo',
       'Toronto', 'Toulouse', 'Tunis', 'Turin', 'Turku', 'Uppsala','Utrecht', 'Valencia', 'Valletta', 'Vancouver', 'Victoria',
       'Vienna', 'Vilnius', 'Warsaw', 'Washington-dc', 'Wellington','Winnipeg', 'Wroclaw', 'Yerevan', 'Zagreb', 'Zurich']

# %%
'Winnipeg'.lower()
# Out:
# 'winnipeg'

# %%
cities_lower = []
for i in cities:
    cities_lower.append(i.lower())

# %%
#cities_lower

# %% [markdown]
# #### We will generate the URL to be used for our data collection.

# %%
url_list = []
for i in cities_lower:
    url_list.append(f"https://teleport.org/cities/{i}/")

# %%
#url_list

# %%
len(url_list)
# Out:
# 262

# %% [markdown]
# ### 3.2 Through Webscrapping we save the description of each city.

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
Description = []
for i in url_list:
    driver.get(i)
    sleep(5)
    my_info = driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(1) > div:nth-child(3) > div > div.summary___1Tz89").text
    Description.append(my_info)
driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/danielaarias/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-35-39fbbb61f52f>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# <ipython-input-35-39fbbb61f52f>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   my_info = driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(1) > div:nth-child(3) > div > div.summary___1Tz89").text

# %%
len(Description)
# Out:
# 262

# %% [markdown]
# ### 3.3  We will obtain the Housing cost, with the price for each type of apartment.

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)

housing = []
        
for i in url_list:
    driver.get(i)
    sleep(5)
    dicc_hou ={"Large_apartment" : "No hay dato",
               "Medium_apartment" :"No hay dato",
               "Small_apartment":"No hay dato",
               "url":i}
    try:
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > select").click()
        driver.implicitly_wait(20)
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > select > option:nth-child(1)").click()
        Large_price=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > div.number___2Gtf5").text
        dicc_hou["Large_apartment"] = Large_price
        driver.implicitly_wait(20)
    except:
        pass
        
    try:
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > select").click()
        driver.implicitly_wait(20)
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > select > option:nth-child(2)").click()
        Medium_price=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > div.number___2Gtf5").text
        dicc_hou["Medium_apartment"] = Medium_price
        driver.implicitly_wait(20)
    except:
        pass
        
    try:
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > select").click()
        driver.implicitly_wait(20)
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > select > option:nth-child(3)").click()
        Small_price=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > div.number___2Gtf5").text
        dicc_hou["Small_apartment"] = Small_price
        driver.implicitly_wait(20)
    except:
        pass

    housing.append(dicc_hou)
        
driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/danielaarias/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-37-697402a51aa3>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-37-697402a51aa3>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(4) > div:nth-child(3) > div:nth-child(2) > div.details___3QNKe > select").click()
# <ipython-input-37-697402a51aa3>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
len(housing)
# Out:
# 262

# %%
#housing

# %% [markdown]
# ###  3.5 Daily Living Cost data

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)

#Daily_living_cost
Daily_living_cost = []

#Monthly_Fitness_Club_Membership = []
#Beer = []
#Monthly_Public_Transport= []
#Lunch = []

for i in url_list:
    if i != 'https://teleport.org/cities/palo-alto/':
        driver.get(i)
        sleep(5)
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(3) > div > h3").click()
        driver.implicitly_wait(20)
        dicc_dlc ={"Monthly_Fitness_Club_Membership" : "No hay dato",
                   "Beer" :"No hay dato",
                   "Monthly_Public_Transport":"No hay dato",
                   "Lunch":"No hay dato",
                   "url":i}
        try:
            Beer_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(3) > table > tbody > tr:nth-child(3) > td").text
            dicc_dlc["Beer"] = Beer_info
            driver.implicitly_wait(20)
        except:
            pass

        try:
            Lunch_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(3) > table > tbody > tr:nth-child(7) > td").text
            dicc_dlc["Lunch"] = Lunch_info
            driver.implicitly_wait(20)
        except:
            pass

        try:
            Fitness_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(3) > table > tbody > tr:nth-child(8) > td").text
            dicc_dlc["Monthly_Fitness_Club_Membership"] = Fitness_info
            driver.implicitly_wait(20)
        except:
            pass

        try:
            Transport_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(3) > table > tbody > tr:nth-child(9) > td").text
            dicc_dlc["Monthly_Public_Transport"] = Transport_info
            driver.implicitly_wait(20)
        except:
            pass
        
        Daily_living_cost.append(dicc_dlc)
        
driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/danielaarias/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-39-f4390669dee8>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-39-f4390669dee8>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(3) > div > h3").click()
# <ipython-input-39-f4390669dee8>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
len(Daily_living_cost)
# Out:
# 261

# %%
#Daily_living_cost

# %%
palo_alto = {"Monthly_Fitness_Club_Membership" : "No hay dato",
                   "Beer" :"No hay dato",
                   "Monthly_Public_Transport":"No hay dato",
                   "Lunch":"No hay dato",
                   "url":"https://teleport.org/cities/palo-alto/"}

# %%
Daily_living_cost_complete = [{'Monthly_Fitness_Club_Membership': '$37.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$62.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/aarhus/'},
 {'Monthly_Fitness_Club_Membership': '$50.00',
  'Beer': '$4.30',
  'Monthly_Public_Transport': '$80.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/adelaide/'},
 {'Monthly_Fitness_Club_Membership': '$52.00',
  'Beer': '$2.90',
  'Monthly_Public_Transport': '$37.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/albuquerque/'},
 {'Monthly_Fitness_Club_Membership': '$83.00',
  'Beer': '$0.68',
  'Monthly_Public_Transport': '$19.00',
  'Lunch': '$5.70',
  'url': 'https://teleport.org/cities/almaty/'},
 {'Monthly_Fitness_Club_Membership': '$49.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$100.00',
  'Lunch': '$18.00',
  'url': 'https://teleport.org/cities/amsterdam/'},
 {'Monthly_Fitness_Club_Membership': '$61.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$57.00',
  'Lunch': '$17.00',
  'url': 'https://teleport.org/cities/anchorage/'},
 {'Monthly_Fitness_Club_Membership': '$9.40',
  'Beer': '$2.10',
  'Monthly_Public_Transport': 'No hay dato',
  'Lunch': '$49.00',
  'url': 'https://teleport.org/cities/andorra/'},
 {'Monthly_Fitness_Club_Membership': '$33.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$30.00',
  'Lunch': '$7.30',
  'url': 'https://teleport.org/cities/ankara/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$22.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/asheville/'},
 {'Monthly_Fitness_Club_Membership': '$30.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$26.00',
  'Lunch': '$4.30',
  'url': 'https://teleport.org/cities/asuncion/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$40.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/athens/'},
 {'Monthly_Fitness_Club_Membership': '$37.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$96.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/atlanta/'},
 {'Monthly_Fitness_Club_Membership': '$48.00',
  'Beer': '$3.80',
  'Monthly_Public_Transport': '$140.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/auckland/'},
 {'Monthly_Fitness_Club_Membership': '$51.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$50.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/austin/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$0.89',
  'Monthly_Public_Transport': '$9.90',
  'Lunch': '$6.40',
  'url': 'https://teleport.org/cities/baku/'},
 {'Monthly_Fitness_Club_Membership': '$16.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$4.20',
  'Lunch': '$43.00',
  'url': 'https://teleport.org/cities/bali/'},
 {'Monthly_Fitness_Club_Membership': '$59.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$68.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/baltimore/'},
 {'Monthly_Fitness_Club_Membership': '$77.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$35.00',
  'Lunch': '$4.20',
  'url': 'https://teleport.org/cities/bangkok/'},
 {'Monthly_Fitness_Club_Membership': '$54.00',
  'Beer': '$0.98',
  'Monthly_Public_Transport': '$62.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/barcelona/'},
 {'Monthly_Fitness_Club_Membership': '$94.00',
  'Beer': '$0.90',
  'Monthly_Public_Transport': '$30.00',
  'Lunch': '$6.70',
  'url': 'https://teleport.org/cities/beijing/'},
 {'Monthly_Fitness_Club_Membership': '$73.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$62.00',
  'Lunch': '$19.00',
  'url': 'https://teleport.org/cities/beirut/'},
 {'Monthly_Fitness_Club_Membership': '$40.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$83.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/belfast/'},
 {'Monthly_Fitness_Club_Membership': '$33.00',
  'Beer': '$0.73',
  'Monthly_Public_Transport': '$31.00',
  'Lunch': '$9.40',
  'url': 'https://teleport.org/cities/belgrade/'},
 {'Monthly_Fitness_Club_Membership': '$30.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$24.00',
  'Lunch': '$3.80',
  'url': 'https://teleport.org/cities/bengaluru/'},
 {'Monthly_Fitness_Club_Membership': '$54.00',
  'Beer': '$4.00',
  'Monthly_Public_Transport': '$90.00',
  'Lunch': '$22.00',
  'url': 'https://teleport.org/cities/bergen/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$1.20',
  'Monthly_Public_Transport': '$100.00',
  'Lunch': '$10.00',
  'url': 'https://teleport.org/cities/berlin/'},
 {'Monthly_Fitness_Club_Membership': '$110.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$91.00',
  'Lunch': '$23.00',
  'url': 'https://teleport.org/cities/bern/'},
 {'Monthly_Fitness_Club_Membership': '$56.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$51.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/bilbao/'},
 {'Monthly_Fitness_Club_Membership': '$34.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$82.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/birmingham/'},
 {'Monthly_Fitness_Club_Membership': '$46.00',
  'Beer': '$0.96',
  'Monthly_Public_Transport': '$35.00',
  'Lunch': '$4.60',
  'url': 'https://teleport.org/cities/bogota/'},
 {'Monthly_Fitness_Club_Membership': '$31.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$36.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/boise/'},
 {'Monthly_Fitness_Club_Membership': '$66.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$45.00',
  'Lunch': '$20.00',
  'url': 'https://teleport.org/cities/bologna/'},
 {'Monthly_Fitness_Club_Membership': '$50.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$33.00',
  'Lunch': '$18.00',
  'url': 'https://teleport.org/cities/bordeaux/'},
 {'Monthly_Fitness_Club_Membership': '$74.00',
  'Beer': '$2.80',
  'Monthly_Public_Transport': '$79.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/boston/'},
 {'Monthly_Fitness_Club_Membership': '$72.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$89.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/boulder/'},
 {'Monthly_Fitness_Club_Membership': '$20.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$11.00',
  'Lunch': '$58.00',
  'url': 'https://teleport.org/cities/bozeman/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$0.85',
  'Monthly_Public_Transport': '$36.00',
  'Lunch': '$6.90',
  'url': 'https://teleport.org/cities/bratislava/'},
 {'Monthly_Fitness_Club_Membership': '$14.00',
  'Beer': '$2.80',
  'Monthly_Public_Transport': '$80.87',
  'Lunch': '$99.00',
  'url': 'https://teleport.org/cities/brighton/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$3.40',
  'Monthly_Public_Transport': '$100.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/brisbane/'},
 {'Monthly_Fitness_Club_Membership': '$40.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$88.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/bristol/'},
 {'Monthly_Fitness_Club_Membership': '$37.00',
  'Beer': '$0.77',
  'Monthly_Public_Transport': '$26.00',
  'Lunch': '$6.10',
  'url': 'https://teleport.org/cities/brno/'},
 {'Monthly_Fitness_Club_Membership': '$49.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$64.00',
  'Lunch': '$19.00',
  'url': 'https://teleport.org/cities/brussels/'},
 {'Monthly_Fitness_Club_Membership': '$52.00',
  'Beer': '$0.76',
  'Monthly_Public_Transport': '$17.00',
  'Lunch': '$7.50',
  'url': 'https://teleport.org/cities/bucharest/'},
 {'Monthly_Fitness_Club_Membership': '$60.00',
  'Beer': '$0.95',
  'Monthly_Public_Transport': '$40.00',
  'Lunch': '$6.50',
  'url': 'https://teleport.org/cities/budapest/'},
 {'Monthly_Fitness_Club_Membership': '$52.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$16.00',
  'Lunch': '$9.20',
  'url': 'https://teleport.org/cities/buenos-aires/'},
 {'Monthly_Fitness_Club_Membership': '$24.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$68.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/buffalo/'},
 {'Monthly_Fitness_Club_Membership': '$30.00',
  'Beer': '$1.00',
  'Monthly_Public_Transport': '$14.00',
  'Lunch': '$5.80',
  'url': 'https://teleport.org/cities/cairo/'},
 {'Monthly_Fitness_Club_Membership': '$55.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$83.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/calgary/'},
 {'Monthly_Fitness_Club_Membership': '$58.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$75.00',
  'Lunch': '$19.00',
  'url': 'https://teleport.org/cities/cambridge/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$30.00',
  'Lunch': '$9.00',
  'url': 'https://teleport.org/cities/cape-town/'},
 {'Monthly_Fitness_Club_Membership': '$4.30',
  'Beer': '$2.90',
  'Monthly_Public_Transport': '$4.50',
  'Lunch': '$4.40',
  'url': 'https://teleport.org/cities/caracas/'},
 {'Monthly_Fitness_Club_Membership': '$39.00',
  'Beer': '$2.50',
  'Monthly_Public_Transport': '$75.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/cardiff/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$24.00',
  'Lunch': '$6.50',
  'url': 'https://teleport.org/cities/casablanca/'},
 {'Monthly_Fitness_Club_Membership': '$54.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$55.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/charleston/'},
 {'Monthly_Fitness_Club_Membership': '$28.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$82.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/charlotte/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$30.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/chattanooga/'},
 {'Monthly_Fitness_Club_Membership': '$27.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$14.00',
  'Lunch': '$3.00',
  'url': 'https://teleport.org/cities/chennai/'},
 {'Monthly_Fitness_Club_Membership': '$39.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$34.00',
  'Lunch': '$2.90',
  'url': 'https://teleport.org/cities/chiang-mai/'},
 {'Monthly_Fitness_Club_Membership': '$59.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$94.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/chicago/'},
 {'Monthly_Fitness_Club_Membership': '$50.00',
  'Beer': '$1.00',
  'Monthly_Public_Transport': '$9.30',
  'Lunch': '$5.20',
  'url': 'https://teleport.org/cities/chisinau/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$2.70',
  'Monthly_Public_Transport': '$81.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/christchurch/'},
 {'Monthly_Fitness_Club_Membership': '$31.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$100.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/cincinnati/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$91.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/cleveland/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$0.79',
  'Monthly_Public_Transport': '$16.00',
  'Lunch': '$6.20',
  'url': 'https://teleport.org/cities/cluj-napoca/'},
 {'Monthly_Fitness_Club_Membership': '$34.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$110.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/cologne/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$64.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/colorado-springs/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$65.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/columbus/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$76.00',
  'Lunch': '$19.00',
  'url': 'https://teleport.org/cities/copenhagen/'},
 {'Monthly_Fitness_Club_Membership': '$52.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$95.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/cork/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$55.00',
  'Lunch': '$5.90',
  'url': 'https://teleport.org/cities/curitiba/'},
 {'Monthly_Fitness_Club_Membership': '$44.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$76.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/dallas/'},
 {'Monthly_Fitness_Club_Membership': '$88.00',
  'Beer': '$1.20',
  'Monthly_Public_Transport': '$32.00',
  'Lunch': '$5.20',
  'url': 'https://teleport.org/cities/dar-es-salaam/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$20.00',
  'Lunch': '$6.10',
  'url': 'https://teleport.org/cities/delhi/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$110.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/denver/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$1.90',
  'Monthly_Public_Transport': '$51.00',
  'Lunch': '$9.90',
  'url': 'https://teleport.org/cities/des-moines/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$2.70',
  'Monthly_Public_Transport': '$49.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/detroit/'},
 {'Monthly_Fitness_Club_Membership': '$140.00',
  'Beer': '$3.80',
  'Monthly_Public_Transport': '$49.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/doha/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$0.80',
  'Monthly_Public_Transport': '$73.00',
  'Lunch': '$9.80',
  'url': 'https://teleport.org/cities/dresden/'},
 {'Monthly_Fitness_Club_Membership': '$100.00',
  'Beer': '$2.90',
  'Monthly_Public_Transport': '$72.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/dubai/'},
 {'Monthly_Fitness_Club_Membership': '$49.00',
  'Beer': '$3.10',
  'Monthly_Public_Transport': '$150.00',
  'Lunch': '$17.00',
  'url': 'https://teleport.org/cities/dublin/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$1.00',
  'Monthly_Public_Transport': '$81.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/dusseldorf/'},
 {'Monthly_Fitness_Club_Membership': '$45.00',
  'Beer': '$2.90',
  'Monthly_Public_Transport': '$81.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/edinburgh/'},
 {'Monthly_Fitness_Club_Membership': '$48.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$72.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/edmonton/'},
 {'Monthly_Fitness_Club_Membership': '$28.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$88.00',
  'Lunch': '$17.00',
  'url': 'https://teleport.org/cities/eindhoven/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$2.80',
  'Monthly_Public_Transport': '$53.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/eugene/'},
 {'Monthly_Fitness_Club_Membership': '$82.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$41.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/florence/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$57.00',
  'Lunch': '$6.80',
  'url': 'https://teleport.org/cities/florianopolis/'},
 {'Monthly_Fitness_Club_Membership': '$25.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$11.00',
  'Lunch': '$44.00',
  'url': 'https://teleport.org/cities/fort-collins/'},
 {'Monthly_Fitness_Club_Membership': '$51.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$98.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/frankfurt/'},
 {'Monthly_Fitness_Club_Membership': '$82.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$15.00',
  'Lunch': '$68.00',
  'url': 'https://teleport.org/cities/fukuoka/'},
 {'Monthly_Fitness_Club_Membership': '$46.00',
  'Beer': '$0.93',
  'Monthly_Public_Transport': '$26.00',
  'Lunch': '$7.70',
  'url': 'https://teleport.org/cities/gdansk/'},
 {'Monthly_Fitness_Club_Membership': '$120.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$83.00',
  'Lunch': '$28.00',
  'url': 'https://teleport.org/cities/geneva/'},
 {'Monthly_Fitness_Club_Membership': '$30.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$8.80',
  'Lunch': '$75.00',
  'url': 'https://teleport.org/cities/gibraltar/'},
 {'Monthly_Fitness_Club_Membership': '$44.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$64.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/glasgow/'},
 {'Monthly_Fitness_Club_Membership': '$46.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$74.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/gothenburg/'},
 {'Monthly_Fitness_Club_Membership': '$49.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$65.00',
  'Lunch': '$17.00',
  'url': 'https://teleport.org/cities/grenoble/'},
 {'Monthly_Fitness_Club_Membership': '$34.00',
  'Beer': '$0.92',
  'Monthly_Public_Transport': '$20.00',
  'Lunch': '$6.10',
  'url': 'https://teleport.org/cities/guadalajara/'},
 {'Monthly_Fitness_Club_Membership': '$67.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$15.00',
  'Lunch': '$5.10',
  'url': 'https://teleport.org/cities/guatemala-city/'},
 {'Monthly_Fitness_Club_Membership': '$45.00',
  'Beer': '$2.50',
  'Monthly_Public_Transport': '$60.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/halifax/'},
 {'Monthly_Fitness_Club_Membership': '$46.00',
  'Beer': '$1.20',
  'Monthly_Public_Transport': '$100.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/hamburg/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$73.00',
  'Lunch': '$10.00',
  'url': 'https://teleport.org/cities/hannover/'},
 {'Monthly_Fitness_Club_Membership': '$40.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$17.00',
  'Lunch': '$7.90',
  'url': 'https://teleport.org/cities/havana/'},
 {'Monthly_Fitness_Club_Membership': '$59.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$71.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/helsinki/'},
 {'Monthly_Fitness_Club_Membership': '$27.00',
  'Beer': '$1.20',
  'Monthly_Public_Transport': '$7.90',
  'Lunch': '$2.20',
  'url': 'https://teleport.org/cities/ho-chi-minh-city/'},
 {'Monthly_Fitness_Club_Membership': '$82.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$60.00',
  'Lunch': '$8.70',
  'url': 'https://teleport.org/cities/hong-kong/'},
 {'Monthly_Fitness_Club_Membership': '$58.00',
  'Beer': '$3.40',
  'Monthly_Public_Transport': '$64.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/honolulu/'},
 {'Monthly_Fitness_Club_Membership': '$37.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$49.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/houston/'},
 {'Monthly_Fitness_Club_Membership': '$25.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$13.00',
  'Lunch': '$3.80',
  'url': 'https://teleport.org/cities/hyderabad/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$64.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/indianapolis/'},
 {'Monthly_Fitness_Club_Membership': '$55.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$56.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/innsbruck/'},
 {'Monthly_Fitness_Club_Membership': '$39.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$50.00',
  'Lunch': '$6.30',
  'url': 'https://teleport.org/cities/istanbul/'},
 {'Monthly_Fitness_Club_Membership': '$34.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$51.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/jacksonville/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$2.50',
  'Monthly_Public_Transport': '$18.00',
  'Lunch': '$3.90',
  'url': 'https://teleport.org/cities/jakarta/'},
 {'Monthly_Fitness_Club_Membership': '$39.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$60.00',
  'Lunch': '$8.50',
  'url': 'https://teleport.org/cities/johannesburg/'},
 {'Monthly_Fitness_Club_Membership': '$45.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$51.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/kansas-city/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$64.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/karlsruhe/'},
 {'Monthly_Fitness_Club_Membership': '$24.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$13.00',
  'Lunch': '$4.00',
  'url': 'https://teleport.org/cities/kathmandu/'},
 {'Monthly_Fitness_Club_Membership': '$22.00',
  'Beer': '$0.54',
  'Monthly_Public_Transport': '$10.00',
  'Lunch': '$4.30',
  'url': 'https://teleport.org/cities/kiev/'},
 {'Monthly_Fitness_Club_Membership': '$49.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$57.00',
  'Lunch': '$5.20',
  'url': 'https://teleport.org/cities/kingston/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$3.10',
  'Monthly_Public_Transport': '$48.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/knoxville/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$1.00',
  'Monthly_Public_Transport': '$28.00',
  'Lunch': '$6.10',
  'url': 'https://teleport.org/cities/krakow/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$35.00',
  'Lunch': '$3.60',
  'url': 'https://teleport.org/cities/kuala-lumpur/'},
 {'Monthly_Fitness_Club_Membership': '$100.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$16.00',
  'Lunch': '$83.00',
  'url': 'https://teleport.org/cities/kyoto/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$0.97',
  'Monthly_Public_Transport': '$39.00',
  'Lunch': '$6.00',
  'url': 'https://teleport.org/cities/lagos/'},
 {'Monthly_Fitness_Club_Membership': '$27.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$5.80',
  'Lunch': '$55.00',
  'url': 'https://teleport.org/cities/la-paz/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$1.20',
  'Monthly_Public_Transport': '$48.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/las-palmas-de-gran-canaria/'},
 {'Monthly_Fitness_Club_Membership': '$28.00',
  'Beer': '$1.90',
  'Monthly_Public_Transport': '$61.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/las-vegas/'},
 {'Monthly_Fitness_Club_Membership': '$100.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$84.00',
  'Lunch': '$24.00',
  'url': 'https://teleport.org/cities/lausanne/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$73.00',
  'Lunch': '$19.00',
  'url': 'https://teleport.org/cities/leeds/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$1.00',
  'Monthly_Public_Transport': '$86.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/leipzig/'},
 {'Monthly_Fitness_Club_Membership': '$40.00',
  'Beer': '$2.50',
  'Monthly_Public_Transport': '$64.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/lille/'},
 {'Monthly_Fitness_Club_Membership': '$53.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$32.00',
  'Lunch': '$4.40',
  'url': 'https://teleport.org/cities/lima/'},
 {'Monthly_Fitness_Club_Membership': '$51.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$45.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/lisbon/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$1.90',
  'Monthly_Public_Transport': '$76.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/liverpool/'},
 {'Monthly_Fitness_Club_Membership': '$56.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$46.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/ljubljana/'},
 {'Monthly_Fitness_Club_Membership': '$77.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$200.00',
  'Lunch': '$18.00',
  'url': 'https://teleport.org/cities/london/'},
 {'Monthly_Fitness_Club_Membership': '$50.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$88.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/los-angeles/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$3.10',
  'Monthly_Public_Transport': '$56.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/louisville/'},
 {'Monthly_Fitness_Club_Membership': '$76.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$48.00',
  'Lunch': '$20.00',
  'url': 'https://teleport.org/cities/luxembourg/'},
 {'Monthly_Fitness_Club_Membership': '$16.00',
  'Beer': '$0.55',
  'Monthly_Public_Transport': '$5.50',
  'Lunch': '$3.10',
  'url': 'https://teleport.org/cities/lviv/'},
 {'Monthly_Fitness_Club_Membership': '$57.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$72.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/lyon/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$64.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/madison/'},
 {'Monthly_Fitness_Club_Membership': '$46.00',
  'Beer': '$1.00',
  'Monthly_Public_Transport': '$71.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/madrid/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$0.80',
  'Monthly_Public_Transport': '$49.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/malaga/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$62.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/malmo/'},
 {'Monthly_Fitness_Club_Membership': '$17.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$4.40',
  'Lunch': '$37.00',
  'url': 'https://teleport.org/cities/managua/'},
 {'Monthly_Fitness_Club_Membership': '$40.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$78.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/manchester/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$0.85',
  'Monthly_Public_Transport': '$20.00',
  'Lunch': '$4.40',
  'url': 'https://teleport.org/cities/manila/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$56.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/marseille/'},
 {'Monthly_Fitness_Club_Membership': '$32.00',
  'Beer': '$0.92',
  'Monthly_Public_Transport': '$29.00',
  'Lunch': '$4.50',
  'url': 'https://teleport.org/cities/medellin/'},
 {'Monthly_Fitness_Club_Membership': '$62.00',
  'Beer': '$4.00',
  'Monthly_Public_Transport': '$110.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/melbourne/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$46.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/memphis/'},
 {'Monthly_Fitness_Club_Membership': '$64.00',
  'Beer': '$1.00',
  'Monthly_Public_Transport': '$18.00',
  'Lunch': '$5.60',
  'url': 'https://teleport.org/cities/mexico-city/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$100.00',
  'Lunch': '$19.00',
  'url': 'https://teleport.org/cities/miami/'},
 {'Monthly_Fitness_Club_Membership': '$75.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$41.00',
  'Lunch': '$18.00',
  'url': 'https://teleport.org/cities/milan/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$62.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/milwaukee/'},
 {'Monthly_Fitness_Club_Membership': '$47.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$70.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/minneapolis-saint-paul/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$0.83',
  'Monthly_Public_Transport': '$15.00',
  'Lunch': '$6.70',
  'url': 'https://teleport.org/cities/minsk/'},
 {'Monthly_Fitness_Club_Membership': '$53.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$51.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/montevideo/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$2.50',
  'Monthly_Public_Transport': '$63.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/montreal/'},
 {'Monthly_Fitness_Club_Membership': '$68.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$36.00',
  'Lunch': '$9.20',
  'url': 'https://teleport.org/cities/moscow/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$10.00',
  'Lunch': '$6.00',
  'url': 'https://teleport.org/cities/mumbai/'},
 {'Monthly_Fitness_Club_Membership': '$56.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$74.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/munich/'},
 {'Monthly_Fitness_Club_Membership': '$81.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$28.00',
  'Lunch': '$6.10',
  'url': 'https://teleport.org/cities/nairobi/'},
 {'Monthly_Fitness_Club_Membership': '$44.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$71.00',
  'Lunch': '$17.00',
  'url': 'https://teleport.org/cities/nantes/'},
 {'Monthly_Fitness_Club_Membership': '$52.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$50.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/naples/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$66.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/nashville/'},
 {'Monthly_Fitness_Club_Membership': '$54.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$53.00',
  'Lunch': '$18.00',
  'url': 'https://teleport.org/cities/new-orleans/'},
 {'Monthly_Fitness_Club_Membership': '$83.00',
  'Beer': '$2.90',
  'Monthly_Public_Transport': '$120.00',
  'Lunch': '$18.00',
  'url': 'https://teleport.org/cities/new-york/'},
 {'Monthly_Fitness_Club_Membership': '$57.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$44.00',
  'Lunch': '$20.00',
  'url': 'https://teleport.org/cities/nice/'},
 {'Monthly_Fitness_Club_Membership': '$58.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$49.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/nicosia/'},
 {'Monthly_Fitness_Club_Membership': '$27.00',
  'Beer': '$2.70',
  'Monthly_Public_Transport': '$45.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/oklahoma-city/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$2.00',
  'Monthly_Public_Transport': '$51.00',
  'Lunch': '$10.00',
  'url': 'https://teleport.org/cities/omaha/'},
 {'Monthly_Fitness_Club_Membership': '$38.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$56.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/orlando/'},
 {'Monthly_Fitness_Club_Membership': '$73.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$84.00',
  'Lunch': '$7.50',
  'url': 'https://teleport.org/cities/osaka/'},
 {'Monthly_Fitness_Club_Membership': '$57.00',
  'Beer': '$3.60',
  'Monthly_Public_Transport': '$84.00',
  'Lunch': '$24.00',
  'url': 'https://teleport.org/cities/oslo/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$89.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/ottawa/'},
 {'Monthly_Fitness_Club_Membership': '$64.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$14.00',
  'Lunch': '$56.00',
  'url': 'https://teleport.org/cities/oulu/'},
 {'Monthly_Fitness_Club_Membership': '$57.00',
  'Beer': '$2.80',
  'Monthly_Public_Transport': '$86.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/oxford/'},
{"Monthly_Fitness_Club_Membership" : "No hay dato",
"Beer" :"No hay dato",
"Monthly_Public_Transport":"No hay dato",
"Lunch":"No hay dato",
"url":"https://teleport.org/cities/palo-alto/"},
 {'Monthly_Fitness_Club_Membership': '$26.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$6.00',
  'Lunch': '$63.00',
  'url': 'https://teleport.org/cities/panama/'},
 {'Monthly_Fitness_Club_Membership': '$72.00',
  'Beer': '$2.70',
  'Monthly_Public_Transport': '$88.00',
  'Lunch': '$17.00',
  'url': 'https://teleport.org/cities/paris/'},
 {'Monthly_Fitness_Club_Membership': '$47.00',
  'Beer': '$3.80',
  'Monthly_Public_Transport': '$83.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/perth/'},
 {'Monthly_Fitness_Club_Membership': '$34.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$88.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/philadelphia/'},
 {'Monthly_Fitness_Club_Membership': '$50.00',
  'Beer': '$0.92',
  'Monthly_Public_Transport': '$18.00',
  'Lunch': '$5.30',
  'url': 'https://teleport.org/cities/phnom-penh/'},
 {'Monthly_Fitness_Club_Membership': '$31.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$58.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/phoenix/'},
 {'Monthly_Fitness_Club_Membership': '$48.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$14.00',
  'Lunch': '$5.20',
  'url': 'https://teleport.org/cities/phuket/'},
 {'Monthly_Fitness_Club_Membership': '$34.00',
  'Beer': '$2.80',
  'Monthly_Public_Transport': '$95.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/pittsburgh/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$94.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/portland-or/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$42.00',
  'Lunch': '$7.70',
  'url': 'https://teleport.org/cities/porto/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$63.00',
  'Lunch': '$7.40',
  'url': 'https://teleport.org/cities/porto-alegre/'},
 {'Monthly_Fitness_Club_Membership': '$45.00',
  'Beer': '$0.82',
  'Monthly_Public_Transport': '$26.00',
  'Lunch': '$7.40',
  'url': 'https://teleport.org/cities/prague/'},
 {'Monthly_Fitness_Club_Membership': '$73.00',
  'Beer': '$2.50',
  'Monthly_Public_Transport': '$12.00',
  'Lunch': '$32.00',
  'url': 'https://teleport.org/cities/providence/'},
 {'Monthly_Fitness_Club_Membership': '$33.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$70.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/quebec/'},
 {'Monthly_Fitness_Club_Membership': '$56.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$13.00',
  'Lunch': '$4.20',
  'url': 'https://teleport.org/cities/quito/'},
 {'Monthly_Fitness_Club_Membership': '$47.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$43.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/raleigh/'},
 {'Monthly_Fitness_Club_Membership': '$87.00',
  'Beer': '$3.90',
  'Monthly_Public_Transport': '$120.00',
  'Lunch': '$26.00',
  'url': 'https://teleport.org/cities/reykjavik/'},
 {'Monthly_Fitness_Club_Membership': '$29.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$63.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/richmond/'},
 {'Monthly_Fitness_Club_Membership': '$50.00',
  'Beer': '$1.20',
  'Monthly_Public_Transport': '$63.00',
  'Lunch': '$7.50',
  'url': 'https://teleport.org/cities/riga/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$61.00',
  'Lunch': '$9.00',
  'url': 'https://teleport.org/cities/rio-de-janeiro/'},
 {'Monthly_Fitness_Club_Membership': '$96.00',
  'Beer': '$1.20',
  'Monthly_Public_Transport': '$42.00',
  'Lunch': '$7.80',
  'url': 'https://teleport.org/cities/riyadh/'},
 {'Monthly_Fitness_Club_Membership': '$31.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$59.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/rochester/'},
 {'Monthly_Fitness_Club_Membership': '$79.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$45.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/rome/'},
 {'Monthly_Fitness_Club_Membership': '$31.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$81.00',
  'Lunch': '$17.00',
  'url': 'https://teleport.org/cities/rotterdam/'},
 {'Monthly_Fitness_Club_Membership': '$33.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$49.00',
  'Lunch': '$7.30',
  'url': 'https://teleport.org/cities/saint-petersburg/'},
 {'Monthly_Fitness_Club_Membership': '$27.00',
  'Beer': '$3.10',
  'Monthly_Public_Transport': '$90.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/salt-lake-city/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$39.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/san-antonio/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$67.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/san-diego/'},
 {'Monthly_Fitness_Club_Membership': '$75.00',
  'Beer': '$2.50',
  'Monthly_Public_Transport': '$93.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/san-francisco-bay-area/'},
 {'Monthly_Fitness_Club_Membership': '$62.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$40.00',
  'Lunch': '$8.50',
  'url': 'https://teleport.org/cities/san-jose/'},
 {'Monthly_Fitness_Club_Membership': '$41.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$35.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/san-juan/'},
 {'Monthly_Fitness_Club_Membership': '$12.00',
  'Beer': '$3.40',
  'Monthly_Public_Transport': 'No hay dato',
  'Lunch': '$42.00',
  'url': 'https://teleport.org/cities/san-luis-obispo/'},
 {'Monthly_Fitness_Club_Membership': '$30.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$25.00',
  'Lunch': '$5.10',
  'url': 'https://teleport.org/cities/san-salvador/'},
 {'Monthly_Fitness_Club_Membership': '$54.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$61.00',
  'Lunch': '$8.00',
  'url': 'https://teleport.org/cities/santiago/'},
 {'Monthly_Fitness_Club_Membership': '$31.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$33.00',
  'Lunch': '$8.20',
  'url': 'https://teleport.org/cities/santo-domingo/'},
 {'Monthly_Fitness_Club_Membership': '$49.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$57.00',
  'Lunch': '$9.30',
  'url': 'https://teleport.org/cities/sao-paulo/'},
 {'Monthly_Fitness_Club_Membership': '$33.00',
  'Beer': '$0.77',
  'Monthly_Public_Transport': '$34.00',
  'Lunch': '$6.50',
  'url': 'https://teleport.org/cities/sarajevo/'},
 {'Monthly_Fitness_Club_Membership': '$44.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$69.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/saskatoon/'},
 {'Monthly_Fitness_Club_Membership': '$55.00',
  'Beer': '$2.50',
  'Monthly_Public_Transport': '$100.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/seattle/'},
 {'Monthly_Fitness_Club_Membership': '$77.00',
  'Beer': '$2.70',
  'Monthly_Public_Transport': '$59.00',
  'Lunch': '$7.90',
  'url': 'https://teleport.org/cities/seoul/'},
 {'Monthly_Fitness_Club_Membership': '$39.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$44.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/seville/'},
 {'Monthly_Fitness_Club_Membership': '$59.00',
  'Beer': '$0.84',
  'Monthly_Public_Transport': '$31.00',
  'Lunch': '$6.20',
  'url': 'https://teleport.org/cities/shanghai/'},
 {'Monthly_Fitness_Club_Membership': '$110.00',
  'Beer': '$4.40',
  'Monthly_Public_Transport': '$73.00',
  'Lunch': '$10.00',
  'url': 'https://teleport.org/cities/singapore/'},
 {'Monthly_Fitness_Club_Membership': '$30.00',
  'Beer': '$0.91',
  'Monthly_Public_Transport': '$28.00',
  'Lunch': '$6.70',
  'url': 'https://teleport.org/cities/skopje/'},
 {'Monthly_Fitness_Club_Membership': '$27.00',
  'Beer': '$0.81',
  'Monthly_Public_Transport': '$34.00',
  'Lunch': '$6.90',
  'url': 'https://teleport.org/cities/sofia/'},
 {'Monthly_Fitness_Club_Membership': '$27.00',
  'Beer': '$1.90',
  'Monthly_Public_Transport': '$70.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/st-louis/'},
 {'Monthly_Fitness_Club_Membership': '$51.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$97.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/stockholm/'},
 {'Monthly_Fitness_Club_Membership': '$44.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$95.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/stuttgart/'},
 {'Monthly_Fitness_Club_Membership': '$68.00',
  'Beer': '$4.40',
  'Monthly_Public_Transport': '$140.00',
  'Lunch': '$11.00',
  'url': 'https://teleport.org/cities/sydney/'},
 {'Monthly_Fitness_Club_Membership': '$56.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$48.00',
  'Lunch': '$5.30',
  'url': 'https://teleport.org/cities/taipei/'},
 {'Monthly_Fitness_Club_Membership': '$62.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$27.00',
  'Lunch': '$10.00',
  'url': 'https://teleport.org/cities/tallinn/'},
 {'Monthly_Fitness_Club_Membership': '$32.00',
  'Beer': '$2.10',
  'Monthly_Public_Transport': '$60.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/tampa-bay-area/'},
 {'Monthly_Fitness_Club_Membership': '$59.00',
  'Beer': '$3.60',
  'Monthly_Public_Transport': '$62.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/tampere/'},
 {'Monthly_Fitness_Club_Membership': '$54.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$17.00',
  'Lunch': '$7.90',
  'url': 'https://teleport.org/cities/tartu/'},
 {'Monthly_Fitness_Club_Membership': '$14.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$4.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/tashkent/'},
 {'Monthly_Fitness_Club_Membership': '$47.00',
  'Beer': '$0.92',
  'Monthly_Public_Transport': '$14.00',
  'Lunch': '$6.80',
  'url': 'https://teleport.org/cities/tbilisi/'},
 {'Monthly_Fitness_Club_Membership': '$35.00',
  'Beer': '$0.76',
  'Monthly_Public_Transport': '$17.00',
  'Lunch': '$5.90',
  'url': 'https://teleport.org/cities/tehran/'},
 {'Monthly_Fitness_Club_Membership': '$79.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$62.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/tel-aviv/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$96.00',
  'Lunch': '$18.00',
  'url': 'https://teleport.org/cities/the-hague/'},
 {'Monthly_Fitness_Club_Membership': '$46.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$35.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/thessaloniki/'},
 {'Monthly_Fitness_Club_Membership': '$98.00',
  'Beer': '$2.20',
  'Monthly_Public_Transport': '$80.00',
  'Lunch': '$9.20',
  'url': 'https://teleport.org/cities/tokyo/'},
 {'Monthly_Fitness_Club_Membership': '$48.00',
  'Beer': '$2.30',
  'Monthly_Public_Transport': '$110.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/toronto/'},
 {'Monthly_Fitness_Club_Membership': '$43.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$62.00',
  'Lunch': '$15.00',
  'url': 'https://teleport.org/cities/toulouse/'},
 {'Monthly_Fitness_Club_Membership': '$29.00',
  'Beer': '$0.90',
  'Monthly_Public_Transport': '$13.00',
  'Lunch': '$3.40',
  'url': 'https://teleport.org/cities/tunis/'},
 {'Monthly_Fitness_Club_Membership': '$52.00',
  'Beer': '$1.40',
  'Monthly_Public_Transport': '$43.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/turin/'},
 {'Monthly_Fitness_Club_Membership': '$64.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$67.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/turku/'},
 {'Monthly_Fitness_Club_Membership': '$45.00',
  'Beer': '$1.80',
  'Monthly_Public_Transport': '$90.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/uppsala/'},
 {'Monthly_Fitness_Club_Membership': '$32.00',
  'Beer': '$1.20',
  'Monthly_Public_Transport': '$95.00',
  'Lunch': '$18.00',
  'url': 'https://teleport.org/cities/utrecht/'},
 {'Monthly_Fitness_Club_Membership': '$42.00',
  'Beer': '$1.10',
  'Monthly_Public_Transport': '$56.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/valencia/'},
 {'Monthly_Fitness_Club_Membership': '$31.00',
  'Beer': '$1.70',
  'Monthly_Public_Transport': '$9.30',
  'Lunch': '$64.00',
  'url': 'https://teleport.org/cities/valletta/'},
 {'Monthly_Fitness_Club_Membership': '$46.00',
  'Beer': '$3.30',
  'Monthly_Public_Transport': '$83.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/vancouver/'},
 {'Monthly_Fitness_Club_Membership': '$40.00',
  'Beer': '$2.60',
  'Monthly_Public_Transport': '$72.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/victoria/'},
 {'Monthly_Fitness_Club_Membership': '$55.00',
  'Beer': '$1.60',
  'Monthly_Public_Transport': '$53.00',
  'Lunch': '$13.00',
  'url': 'https://teleport.org/cities/vienna/'},
 {'Monthly_Fitness_Club_Membership': '$63.00',
  'Beer': '$1.30',
  'Monthly_Public_Transport': '$37.00',
  'Lunch': '$7.80',
  'url': 'https://teleport.org/cities/vilnius/'},
 {'Monthly_Fitness_Club_Membership': '$36.00',
  'Beer': '$0.91',
  'Monthly_Public_Transport': '$30.00',
  'Lunch': '$7.30',
  'url': 'https://teleport.org/cities/warsaw/'},
 {'Monthly_Fitness_Club_Membership': '$80.00',
  'Beer': '$3.00',
  'Monthly_Public_Transport': '$190.00',
  'Lunch': '$16.00',
  'url': 'https://teleport.org/cities/washington-dc/'},
 {'Monthly_Fitness_Club_Membership': '$37.00',
  'Beer': '$3.80',
  'Monthly_Public_Transport': '$110.00',
  'Lunch': '$12.00',
  'url': 'https://teleport.org/cities/wellington/'},
 {'Monthly_Fitness_Club_Membership': '$40.00',
  'Beer': '$2.90',
  'Monthly_Public_Transport': '$66.00',
  'Lunch': '$14.00',
  'url': 'https://teleport.org/cities/winnipeg/'},
 {'Monthly_Fitness_Club_Membership': '$27.00',
  'Beer': '$0.93',
  'Monthly_Public_Transport': '$24.00',
  'Lunch': '$7.20',
  'url': 'https://teleport.org/cities/wroclaw/'},
 {'Monthly_Fitness_Club_Membership': '$57.00',
  'Beer': '$0.89',
  'Monthly_Public_Transport': '$13.00',
  'Lunch': '$6.30',
  'url': 'https://teleport.org/cities/yerevan/'},
 {'Monthly_Fitness_Club_Membership': '$45.00',
  'Beer': '$1.50',
  'Monthly_Public_Transport': '$61.00',
  'Lunch': '$9.10',
  'url': 'https://teleport.org/cities/zagreb/'},
 {'Monthly_Fitness_Club_Membership': '$100.00',
  'Beer': '$2.40',
  'Monthly_Public_Transport': '$100.00',
  'Lunch': '$29.00',
  'url': 'https://teleport.org/cities/zurich/'}]

# %%
len(Daily_living_cost_complete)
# Out:
# 262

# %% [markdown]
# ### 3.6 Travel, Safety & Education

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)

#Travel_Connectivity
#Safety
#Education
Travel_Safety_Education = []

#Airport_hub = []
#Intercity_train_connectivity= []
#Gun_related_deaths = []
#Guns_per_residents= []
#Pisa_ranking = []
#Best_university = []

for i in url_list:
    driver.get(i)
    sleep(5)
    dicc_tse ={"Airport_hub" : "No hay dato",
               "Intercity_train_connectivity" :"No hay dato",
               "Gun_related_deaths":"No hay dato",
               "Guns_per_residents": "No hay dato",
               "Pisa_ranking":"No hay dato",
               "Best_university":"No hay dato",
               "url":i}
    if i != 'https://teleport.org/cities/palo-alto/':
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            Airpot_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > table > tbody > tr:nth-child(1) > td").text
            dicc_tse["Airport_hub"] = Airpot_info
            driver.implicitly_wait(20) 
        except:
            pass
        try:
            Train_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > table > tbody > tr:nth-child(3) > td").text
            dicc_tse["Intercity_train_connectivity"] = Train_info
            driver.implicitly_wait(20)
        except:
            pass
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(9) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            Deaths_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(9) > table > tbody > tr:nth-child(2) > td").text
            dicc_tse["Gun_related_deaths"] = Deaths_info
            driver.implicitly_wait(20)
        except:
            pass
        try:
            Guns_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(9) > table > tbody > tr:nth-child(3) > td").text
            dicc_tse["Guns_per_residents"] = Guns_info
            driver.implicitly_wait(20)  
        except:
            pass
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(11) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            Pisa_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(11) > table > tbody > tr:nth-child(7) > td").text
            dicc_tse["Pisa_ranking"] = Pisa_info
            driver.implicitly_wait(20)
        except:
            pass
        try:
            University_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(11) > table > tbody > tr:nth-child(1) > td").text
            dicc_tse["Best_university"] = University_info
            driver.implicitly_wait(20)         
        except:
            pass

    Travel_Safety_Education.append(dicc_tse)   
    
driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/danielaarias/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-45-a088c9455dd7>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-45-a088c9455dd7>:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > div > h3").click()
# <ipython-input-45-a088c9455dd7>:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
len(Travel_Safety_Education)
# Out:
# 248

# %%
### 3.7 Airport

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)

Airport = []


for i in url_list:
    driver.get(i)
    sleep(5)
    dicc_air ={"Airport_score" : "No hay dato",
               "url":i}
    if i != 'https://teleport.org/cities/palo-alto/':
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            Airpot_scinfo=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > table > tbody > tr:nth-child(2) > td").text
            dicc_air["Airport_score"] = Airpot_scinfo
            driver.implicitly_wait(20) 
        except:
            pass

    Airport.append(dicc_air)   
    
driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/danielaarias/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-20-8e09457c27fe>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-20-8e09457c27fe>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > div > h3").click()
# <ipython-input-20-8e09457c27fe>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
### 3.8 Poblation

# %%
def funcion_poblacion(lista):
    resultado=[]
    try:
        for i in lista:
            res = requests.get(i)
            soup = BeautifulSoup(res.content,"html.parser")
            textaco = soup.findAll("div", {"class":"figureLabel___2OYTW"})
            resultado.append(textaco[0].getText())
    except:
        resultado.append("No hay dato")
    return resultado

# %%
Poblacion = funcion_poblacion(url_list)

# %%
len(Poblacion)
# Out:
# 262

# %% [markdown]
# ## Tolerance, Taxation, People,  Good Country Index, Environmental quality

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)

#Tolerance
#Taxation
#Leisure&Culture
#Economy
ttge = []


for i in url_list:
    driver.get(i)
    sleep(5)
    dicc_ttge ={"Homosexuality_acceptance" : "No hay dato",
               "LGBT_adoption_rights" :"No hay dato",
               "LGBT_homosexuality_rights":"No hay dato",
               "LGBT_marriage_rights": "No hay dato",
               "VAT_Sales_Tax":"No hay dato",
               "Art_galleries":"No hay dato",
               "Concert_venues":"No hay dato",
               "Museums":"No hay dato",
               "Sport_venues": "No hay dato",
               "Currency_for_urban_area": "No hay dato",
               "GDP_per_capita":"No hay dato",
               "url":i}
    
    if i != 'https://teleport.org/cities/palo-alto/':
        
        #Tolerance
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(17) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            homosex_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(17) > table > tbody > tr:nth-child(1) > td").text
            dicc_ttge["Homosexuality_acceptance"] = homosex_info
            driver.implicitly_wait(20) 
        except:
            pass
        try:
            adoption_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(17) > table > tbody > tr:nth-child(4) > td").text
            dicc_ttge["LGBT_adoption_rights"] = adoption_info
            driver.implicitly_wait(20)
        except:
            pass
        try:
            rights_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(17) > table > tbody > tr:nth-child(11) > td").text
            dicc_ttge["LGBT_homosexuality_rights"] = rights_info
            driver.implicitly_wait(20)
        except:
            pass
        try:
            marriage_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(17) > table > tbody > tr:nth-child(13) > td").text
            dicc_ttge["LGBT_marriage_rights"] = marriage_info
            driver.implicitly_wait(20)
        except:
            pass
        
        #Taxation
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(14) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            VAT_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(14) > table > tbody > tr:nth-child(5) > td").text
            dicc_ttge["VAT_Sales_Tax"] = VAT_info
            driver.implicitly_wait(20)
        except:
            pass
        
        #Leisure&Culture
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(16) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            art_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(16) > table > tbody > tr:nth-child(1) > td").text
            dicc_ttge["Art_galleries"] = art_info
            driver.implicitly_wait(20)  
        except:
            pass
        try:
            concert_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(16) > table > tbody > tr:nth-child(7) > td").text
            dicc_ttge["Concert_venues"] = concert_info
            driver.implicitly_wait(20)
        except:
            pass
        try:
            museums_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(16) > table > tbody > tr:nth-child(11) > td").text
            dicc_ttge["Museums"] = museums_info
            driver.implicitly_wait(20)         
        except:
            pass
        try:
            sport_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(16) > table > tbody > tr:nth-child(15) > td").text
            dicc_ttge["Sport_venues"] = sport_info
            driver.implicitly_wait(20)
        except:
            pass
        
        #Economy
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(13) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            currency_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(13) > table > tbody > tr:nth-child(2) > td").text
            dicc_ttge["Currency_for_urban_area"] = currency_info
            driver.implicitly_wait(20)         
        except:
            pass
        try:
            GDP_info=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(13) > table > tbody > tr:nth-child(5) > td").text
            dicc_ttge["GDP_per_capita"] = GDP_info
            driver.implicitly_wait(20)         
        except:
            pass

    ttge.append(dicc_ttge)
    
driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/danielaarias/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-223-6757c7f02104>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-223-6757c7f02104>:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(17) > div > h3").click()
# <ipython-input-223-6757c7f02104>:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
len(ttge)
# Out:
# 262

# %%
#ttge

# %% [markdown]
# #### Growth_in_2015_2020

# %%
demo=[]
    
for i in url_list:
    dicc_demogra={'Growth':'No hay dato','GDP_per_capita': 'No hay dato','Unemployment': 'No hay dato', 'url':i}
    try:
        res = requests.get(i)
        soup = BeautifulSoup(res.content,"html.parser")
        textaco = soup.findAll("div", {"class":"figureLabel___2OYTW"})
        dicc_demogra["Growth"] = textaco[2].getText()
    except:
        pass
                  
    try:
        dicc_demogra["GDP_per_capita"] = textaco[6].getText()
    except:
        pass
                  
    try:
        dicc_demogra["Unemployment"] = textaco[7].getText()
    except:
        pass
                
    demo.append(dicc_demogra)

# %%
data = Daily_living_cost + Travel_Safety_Education + housing

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#   Monthly_Fitness_Club_Membership   Beer Monthly_Public_Transport   Lunch  \
# 0                          $37.00  $1.70                   $62.00  $15.00
# 1                          $50.00  $4.30                   $80.00  $13.00
# 2                          $52.00  $2.90                   $37.00  $12.00
# 3                          $83.00  $0.68                   $19.00   $5.70
# 4                          $49.00  $2.10                  $100.00  $18.00
#
#                                         url Airport_hub  \
# 0       https://teleport.org/cities/aarhus/         NaN
# 1     https://teleport.org/cities/adelaide/         NaN
# 2  https://teleport.org/cities/albuquerque/         NaN
# 3       https://teleport.org/cities/almaty/         NaN
# 4    https://teleport.org/cities/amsterdam/         NaN
#
#   Intercity_train_connectivity Gun_related_deaths Guns_per_residents  \
# 0                          NaN                NaN                NaN
# ...

# %%
df.shape
# Out:
# (785, 14)

# %%
data2 = Travel_Safety_Education

# %%
data3 = Daily_living_cost

# %%
df2 = pd.DataFrame(data2)

# %%
df2.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#                                         url
# 0       https://teleport.org/cities/aarhus/
# 1     https://teleport.org/cities/adelaide/
# 2  https://teleport.org/cities/albuquerque/
# 3       https://teleport.org/cities/almaty/
# ...

# %%
df3 = pd.DataFrame(data3)

# %%
df4 = df2.join(df3, lsuffix="_uno", rsuffix="_otro")

# %%
df4.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#                                     url_uno Monthly_Fitness_Club_Membership  \
# 0       https://teleport.org/cities/aarhus/                          $37.00
# ...

# %%
data4= housing

# %%
df5 = pd.DataFrame(data4)

# %%
df5.head()
# Out:
#   Large_apartment Medium_apartment Small_apartment  \
# 0           $1700            $1300            $840
# 1           $1500            $1200           $1000
# 2           $1200             $950            $760
# 3            $620             $480            $340
# 4           $2400            $2000           $1600
#
#                                         url
# 0       https://teleport.org/cities/aarhus/
# 1     https://teleport.org/cities/adelaide/
# 2  https://teleport.org/cities/albuquerque/
# 3       https://teleport.org/cities/almaty/
# 4    https://teleport.org/cities/amsterdam/

# %%
df6 = df4.join(df5, lsuffix="_uno", rsuffix="_otro")

# %%
df6.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#                                     url_uno Monthly_Fitness_Club_Membership  \
# 0       https://teleport.org/cities/aarhus/                          $37.00
# ...

# %%
df7 = df6.copy()

# %%
df7["cities"] = cities

# %%
df7.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#                                     url_uno Monthly_Fitness_Club_Membership  \
# 0       https://teleport.org/cities/aarhus/                          $37.00
# ...

# %%
df7["Description"] = Description

# %%
### Airport

# %%
len(Airport)
# Out:
# 262

# %%
air = pd.DataFrame(Airport)

# %%
air.to_csv("../Data/air.csv")

# %%
df7.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#                                     url_uno Monthly_Fitness_Club_Membership  \
# 0       https://teleport.org/cities/aarhus/                          $37.00
# ...

# %% [markdown]
# ### Población:

# %%
df7["Poblacion"] = Poblacion

# %%
df7.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#                                     url_uno Monthly_Fitness_Club_Membership  \
# 0       https://teleport.org/cities/aarhus/                          $37.00
# ...

# %% [markdown]
# ### Exportaremos los datos conseguidos hasta el momento, para resguardarlos como primera copia.

# %%
# !pwd
# Out:
# /Users/danielaarias/Ironhack/Choose-to-live-better/Notebooks

# %%
df7.to_csv("../Data/primer_web_scrapping.csv")

# %%
df8 = pd.DataFrame(ttge)

# %%
#df8.head()

# %%
#df7.head()

# %%
df9 = df7.join(df8, lsuffix="_uno", rsuffix="_otro")
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack2/lib/python3.8/site-packages/pandas/core/frame.py:9130: FutureWarning: Passing 'suffixes' which cause duplicate columns {'url_uno'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(

# %%
df9.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#                                     url_uno Monthly_Fitness_Club_Membership  \
# 0       https://teleport.org/cities/aarhus/                          $37.00
# ...

# %%
df9.to_csv("../Data/segundo_web_scrapping.csv")

# %% [markdown]
# ### Seguimos recolectando datitos

# %%
##Puedo agregar a este bucle la variable "Población"

# %%
len(demo)
# Out:
# 262

# %%
df10 = pd.DataFrame(demo)

# %%
df10
# Out:
#     Growth GDP_per_capita Unemployment  \
# 0       5%        $44,343           4%
# 1       7%        $46,433           6%
# 2       7%        $54,597           5%
# 3       9%        $24,020           6%
# 4       3%        $47,355           6%
# ..     ...            ...          ...
# 257     3%        $44,843           7%
# 258    -1%        $25,105          10%
# 259     2%         $7,374          18%
# 260     1%        $20,889          16%
# 261     6%        $58,087           3%
#
#                                           url
# 0         https://teleport.org/cities/aarhus/
# 1       https://teleport.org/cities/adelaide/
# 2    https://teleport.org/cities/albuquerque/
# 3         https://teleport.org/cities/almaty/
# 4      https://teleport.org/cities/amsterdam/
# ..                                        ...
# 257     https://teleport.org/cities/winnipeg/
# 258      https://teleport.org/cities/wroclaw/
# 259      https://teleport.org/cities/yerevan/
# ...

# %%
df9 = pd.read_csv("../Data/segundo_web_scrapping.csv")

# %%
df9.columns
# Out:
# Index(['Unnamed: 0', 'Airport_hub', 'Intercity_train_connectivity',
#        'Gun_related_deaths', 'Guns_per_residents', 'Pisa_ranking',
#        'Best_university', 'url_uno', 'Monthly_Fitness_Club_Membership', 'Beer',
#        'Monthly_Public_Transport', 'Lunch', 'url_otro', 'Large_apartment',
#        'Medium_apartment', 'Small_apartment', 'url_uno.1', 'cities',
#        'Description', 'Poblacion', 'Homosexuality_acceptance',
#        'LGBT_adoption_rights', 'LGBT_homosexuality_rights',
#        'LGBT_marriage_rights', 'VAT_Sales_Tax', 'Art_galleries',
#        'Concert_venues', 'Museums', 'Sport_venues', 'Currency_for_urban_area',
#        'GDP_per_capita', 'url_otro.1'],
#       dtype='object')

# %%
df9.drop(["Unnamed: 0", "url_otro", "url_uno.1","url_otro.1"], axis=1, inplace=True)

# %%
df9.columns
# Out:
# Index(['Airport_hub', 'Intercity_train_connectivity', 'Gun_related_deaths',
#        'Guns_per_residents', 'Pisa_ranking', 'Best_university', 'url_uno',
#        'Monthly_Fitness_Club_Membership', 'Beer', 'Monthly_Public_Transport',
#        'Lunch', 'Large_apartment', 'Medium_apartment', 'Small_apartment',
#        'cities', 'Description', 'Poblacion', 'Homosexuality_acceptance',
#        'LGBT_adoption_rights', 'LGBT_homosexuality_rights',
#        'LGBT_marriage_rights', 'VAT_Sales_Tax', 'Art_galleries',
#        'Concert_venues', 'Museums', 'Sport_venues', 'Currency_for_urban_area',
#        'GDP_per_capita'],
#       dtype='object')

# %%
df11 = df9.join(df10, lsuffix="_uno", rsuffix="_otro")

# %%
df11.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#                                     url_uno Monthly_Fitness_Club_Membership  \
# 0       https://teleport.org/cities/aarhus/                          $37.00
# ...

# %%
df11.columns
# Out:
# Index(['Airport_hub', 'Intercity_train_connectivity', 'Gun_related_deaths',
#        'Guns_per_residents', 'Pisa_ranking', 'Best_university', 'url_uno',
#        'Monthly_Fitness_Club_Membership', 'Beer', 'Monthly_Public_Transport',
#        'Lunch', 'Large_apartment', 'Medium_apartment', 'Small_apartment',
#        'cities', 'Description', 'Poblacion', 'Homosexuality_acceptance',
#        'LGBT_adoption_rights', 'LGBT_homosexuality_rights',
#        'LGBT_marriage_rights', 'VAT_Sales_Tax', 'Art_galleries',
#        'Concert_venues', 'Museums', 'Sport_venues', 'Currency_for_urban_area',
#        'GDP_per_capita_uno', 'Growth', 'GDP_per_capita_otro', 'Unemployment',
#        'url'],
#       dtype='object')

# %%
df11.drop(["url_uno"], axis=1, inplace=True)

# %%
df11.to_csv("../Data/tercer_web_scrapping.csv")

# %%
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)

Airport = []


for i in url_list:
    driver.get(i)
    sleep(5)
    dicc_air ={"Airport_score" : "No hay dato",
               "url":i}
    if i != 'https://teleport.org/cities/palo-alto/':
        driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > div > h3").click()
        driver.implicitly_wait(20)
        try:
            Airpot_scinfo=driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > table > tbody > tr:nth-child(2) > td").text
            dicc_air["Airport_score"] = Airpot_scinfo
            driver.implicitly_wait(20) 
        except:
            pass

    Airport.append(dicc_air)   
    
driver.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/danielaarias/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-16-8e09457c27fe>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-16-8e09457c27fe>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector("#container > div > main > div > div.contents___1nRSJ > div > div.container___3R5n9 > article:nth-child(2) > div.contents___mczKq > section:nth-child(6) > div > h3").click()
# <ipython-input-16-8e09457c27fe>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
df11["Airport_score"] = Airport

# %%
df11.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#   Monthly_Fitness_Club_Membership   Beer Monthly_Public_Transport   Lunch  \
# 0                          $37.00  $1.70                   $62.00  $15.00
# 1                          $50.00  $4.30                   $80.00  $13.00
# ...

# %%
##A partir de aca empiezan las variable Climate & Good Country Index

# %%
#Esta es la funcion que funciono bien:

# %%
clima = []
for i in url_list:
    dicc_clima={'Climate':'No hay dato','url':i}
    try:
        res = requests.get(i)
        soup = BeautifulSoup(res.content,"html.parser")
        textaco = soup.findAll("div", {"class":"sunshine___16aRO"})
        dicc_clima["Climate"] = textaco[0].getText()
    except:
        pass
    clima.append(dicc_clima)

# %%
#clima

# %%
datos_clima = clima

# %%
datos_clima
# Out:
# [{'Climate': 'No hay dato', 'url': 'https://teleport.org/cities/aarhus/'},
#  {'Climate': '12.6', 'url': 'https://teleport.org/cities/adelaide/'},
#  {'Climate': '168', 'url': 'https://teleport.org/cities/albuquerque/'},
#  {'Climate': '64', 'url': 'https://teleport.org/cities/almaty/'},
#  {'Climate': '12.9', 'url': 'https://teleport.org/cities/amsterdam/'},
#  {'Climate': '61', 'url': 'https://teleport.org/cities/anchorage/'},
#  {'Climate': 'No hay dato', 'url': 'https://teleport.org/cities/andorra/'},
#  {'Climate': '243', 'url': 'https://teleport.org/cities/ankara/'},
#  {'Climate': '101', 'url': 'https://teleport.org/cities/asheville/'},
#  {'Climate': '12.5', 'url': 'https://teleport.org/cities/asuncion/'},
#  {'Climate': '266.7', 'url': 'https://teleport.org/cities/athens/'},
#  {'Climate': '110', 'url': 'https://teleport.org/cities/atlanta/'},
#  {'Climate': '182.9', 'url': 'https://teleport.org/cities/auckland/'},
# ...

# %%
df12 = pd.DataFrame(datos_clima)

# %%
df12.head()
# Out:
#        Climate                                       url
# 0  No hay dato       https://teleport.org/cities/aarhus/
# 1         12.6     https://teleport.org/cities/adelaide/
# 2          168  https://teleport.org/cities/albuquerque/
# 3           64       https://teleport.org/cities/almaty/
# 4         12.9    https://teleport.org/cities/amsterdam/

# %%
df11["Average_Annual_percent_sunshine"] = df12["Climate"]

# %%
df11.head()
# Out:
#   Airport_hub Intercity_train_connectivity Gun_related_deaths  \
# 0           8                         0.59                  1
# 1          26                         0.17                  1
# 2          23                         0.11                 16
# 3          45                         0.66                  1
# 4         237                         0.68                  1
#
#   Guns_per_residents Pisa_ranking           Best_university  \
# 0                 12           13         Aarhus University
# 1                 24           16    University of Adelaide
# 2                328           24  University of New Mexico
# 3                  1           39                    427.97
# 4                  4           10   University of Amsterdam
#
#   Monthly_Fitness_Club_Membership   Beer Monthly_Public_Transport   Lunch  \
# 0                          $37.00  $1.70                   $62.00  $15.00
# 1                          $50.00  $4.30                   $80.00  $13.00
# ...

# %%
df11.to_csv("../Data/ultimo_web_scrapping.csv")
